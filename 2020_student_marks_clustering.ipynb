# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data1 = pd.read_csv(r'C:\Users\vinee\OneDrive\Desktop\Fulltime\Resume_2020\datasets\final_grades.csv')

# %%
data1.head()
# Out:
#    Student ID  ES 1.1 \n(2 points)  ES 1.2 \n(3 points)  ES 2.1\n(2 points)  \
# 0           1                  2.0                  3.0                 1.0
# 1           2                  2.0                  3.0                 2.0
# 2           4                  2.0                  3.0                 1.0
# 3           5                  2.0                  3.0                 2.0
# 4           7                  2.0                  3.0                 1.0
#
#    ES 2.2\n(3 points)  ES 3.1\n(1 points)  ES 3.2\n(2 points)  \
# 0                 0.5                 1.0                 2.0
# 1                 0.5                 1.0                 2.0
# 2                 0.5                 1.0                 2.0
# 3                 1.5                 1.0                 2.0
# 4                 1.5                 1.0                 2.0
#
#    ES 3.3\n(2 points)  ES 3.4\n(2 points)  ES 3.5\n(3 points)  \
# 0                 2.0                 2.0                 3.0
# 1                 0.0                 2.0                 3.0
# 2                 0.0                 2.0                 0.0
# 3                 2.0                 2.0                 3.0
# 4                 2.0                 2.0                 3.0
#
#    ES 4.1\n(15 points)  ES 4.2\n(10 points)  ES 5.1\n(2 points)  \
# 0                 15.0                 10.0                 2.0
# 1                 15.0                  2.0                 0.0
# 2                  3.0                  4.0                 0.0
# 3                  3.0                  2.0                 1.5
# 4                 15.0                 10.0                 1.0
#
#    ES 5.2\n(10 points)  ES 5.3\n(3 points)  ES 6.1\n(25 points)  \
# 0                 10.0                 3.0                 25.0
# 1                  5.0                 1.5                  5.0
# 2                  1.5                 0.0                  5.0
# 3                  9.0                 1.5                  2.0
# 4                  2.5                 0.0                 20.0
#
#    ES 6.2\n(15 points)  TOTAL\n(100 points)
# 0                 13.0                 94.5
# 1                  0.0                 44.0
# 2                  5.0                 30.0
# 3                  1.0                 38.5
# 4                 12.0                 78.0

# %%
data2 = pd.read_csv(r'C:\Users\vinee\OneDrive\Desktop\Fulltime\Resume_2020\datasets\intermediate_grades.csv')

# %%
data2.head()
# Out:
#    Student Id  Session 2  Session 3  Session 4  Session 5  Session 6
# 0           1        5.0        0.0        4.5        4.0       2.25
# 1           2        4.0        3.5        4.5        4.0       1.00
# 2           3        3.5        3.5        4.5        4.0       0.00
# 3           4        6.0        4.0        5.0        3.5       2.75
# 4           5        5.0        4.0        5.0        4.0       2.75

# %%
data1.describe()
# Out:
#        Student ID  ES 1.1 \n(2 points)  ES 1.2 \n(3 points)  \
# count   62.000000            62.000000            62.000000
# mean    53.612903             1.879032             2.846774
# std     30.514364             0.391356             0.379697
# min      1.000000             0.000000             1.500000
# 25%     30.750000             2.000000             3.000000
# 50%     55.500000             2.000000             3.000000
# 75%     76.500000             2.000000             3.000000
# max    106.000000             2.000000             3.000000
#
#        ES 2.1\n(2 points)  ES 2.2\n(3 points)  ES 3.1\n(1 points)  \
# count           62.000000           62.000000           62.000000
# mean             1.322581            1.112903            0.967742
# std              0.566097            0.911760            0.153403
# min              0.000000            0.000000            0.000000
# 25%              1.000000            0.500000            1.000000
# 50%              1.000000            0.500000            1.000000
# 75%              2.000000            2.000000            1.000000
# max              2.000000            3.000000            1.000000
#
#        ES 3.2\n(2 points)  ES 3.3\n(2 points)  ES 3.4\n(2 points)  \
# count           62.000000           62.000000           62.000000
# mean             1.838710            1.145161            1.838710
# std              0.549024            0.985082            0.549024
# min              0.000000            0.000000            0.000000
# 25%              2.000000            0.000000            2.000000
# 50%              2.000000            2.000000            2.000000
# 75%              2.000000            2.000000            2.000000
# max              2.000000            2.000000            2.000000
#
#        ES 3.5\n(3 points)  ES 4.1\n(15 points)  ES 4.2\n(10 points)  \
# count           62.000000            62.000000            62.000000
# mean             2.258065             9.467742             4.717742
# std              1.292291             5.699346             3.484887
# min              0.000000             0.000000             0.000000
# 25%              2.250000             4.000000             2.000000
# 50%              3.000000            12.000000             4.000000
# 75%              3.000000            15.000000             8.375000
# max              3.000000            15.000000            10.000000
#
#        ES 5.1\n(2 points)  ES 5.2\n(10 points)  ES 5.3\n(3 points)  \
# count           62.000000            62.000000           62.000000
# mean             0.854839             4.080645            1.290323
# std              0.821769             3.794078            1.054065
# min              0.000000             0.000000            0.000000
# 25%              0.000000             0.000000            0.000000
# 50%              1.000000             3.500000            1.500000
# 75%              1.875000             7.500000            1.875000
# max              2.000000            10.000000            3.000000
#
#        ES 6.1\n(25 points)  ES 6.2\n(15 points)  TOTAL\n(100 points)
# count            62.000000            62.000000            62.000000
# mean              8.967742             5.169355            49.758065
# std               9.155698             5.169221            26.090596
# min               0.000000             0.000000             8.500000
# 25%               0.000000             0.000000            30.000000
# 50%               5.000000             5.000000            45.000000
# 75%              15.750000            10.000000            69.500000
# max              25.000000            15.000000            97.500000

# %%
data1.shape
# Out:
# (62, 18)

# %%
data2.shape
# Out:
# (115, 6)

# %%
data1.isnull().sum()
# Out:
# Student ID             0
# ES 1.1 \n(2 points)    0
# ES 1.2 \n(3 points)    0
# ES 2.1\n(2 points)     0
# ES 2.2\n(3 points)     0
# ES 3.1\n(1 points)     0
# ES 3.2\n(2 points)     0
# ES 3.3\n(2 points)     0
# ES 3.4\n(2 points)     0
# ES 3.5\n(3 points)     0
# ES 4.1\n(15 points)    0
# ES 4.2\n(10 points)    0
# ES 5.1\n(2 points)     0
# ES 5.2\n(10 points)    0
# ES 5.3\n(3 points)     0
# ES 6.1\n(25 points)    0
# ES 6.2\n(15 points)    0
# TOTAL\n(100 points)    0
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# Student Id    0
# Session 2     0
# Session 3     0
# Session 4     0
# Session 5     0
# Session 6     0
# dtype: int64

# %%
# making a heatmap  of the final grades data

plt.rcParams['figure.figsize'] = (15, 15)
sns.heatmap(data1, annot = True)
plt.title('Heatmap for the Final Grades Data',fontsize = 30)
plt.show()

# %%
# making a heat map for the intermediate grades data

plt.rcParams['figure.figsize'] = (15, 15)
sns.heatmap(data2, cmap = 'Blues', annot = True)
plt.title('Heatmap for the Final Grades Data',fontsize = 30)
plt.show()

# %%
# looking at the distribution of the total marks of the students

plt.rcParams['figure.figsize'] = (15, 8)
sns.distplot(data1['TOTAL\n(100 points)'], color = 'orange')
plt.title('Distribution of Total Marks among 52 Students', fontsize = 30)
plt.xlabel('Marks', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.distplot(data2['Session 2'], color = 'purple')
plt.title('Distribution of Session2 Marks among 115  Students', fontsize = 30)
plt.xlabel('Marks', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.distplot(data2['Session 3'], color = 'violet')
plt.title('Distribution of Session 3 among 115  Students', fontsize = 30)
plt.xlabel('Marks', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.distplot(data2['Session 4'], color = 'pink')
plt.title('Distribution of Session 4 Marks among 115  Students', fontsize = 30)
plt.xlabel('Marks', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.distplot(data2['Session 5'], color = 'red')
plt.title('Distribution of Session 5 Marks among 115 Students', fontsize = 30)
plt.xlabel('Marks', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.distplot(data2['Session 6'], color = 'yellow')
plt.title('Distribution of Session 6 Marks among 115 Students', fontsize = 30)
plt.xlabel('Marks', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(data1['Student ID'], data1['ES 1.1 \n(2 points)'], 'red')

plt.title('Time Series for Students Performance in Test-1', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(data1['Student ID'], data1['ES 1.2 \n(3 points)'], 'blue')

plt.title('Time Series for Students Performance in different Test-2', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(data1['Student ID'], data1['ES 2.1\n(2 points)'], 'green')

plt.title('Time Series for Students Performance in Test-3', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(data1['Student ID'], data1['ES 2.2\n(3 points)'], 'yellow')

plt.title('Time Series for Students Performance in Test-4', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(data1['Student ID'], data1['ES 3.1\n(1 points)'], 'black')

plt.title('Time Series for Students Performance in Test-5', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(data1['Student ID'], data1['ES 3.2\n(2 points)'], 'purple')

plt.title('Time Series for Students Performance in Test-6', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(data1['Student ID'], data1['ES 3.3\n(2 points)'], 'brown')

plt.title('Time Series for Students Performance in Test-7', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(data1['Student ID'], data1['ES 3.4\n(2 points)'], 'magenta')

plt.title('Time Series for Students Performance in Test-8', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(data1['Student ID'], data1['ES 5.2\n(10 points)'], 'lightgreen')

plt.title('Time Series for Students Performance in Test-13', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(data1['Student ID'], data1['ES 5.3\n(3 points)'], 'lightblue')

plt.title('Time Series for Students Performance in Test-14', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(data1['Student ID'], data1['ES 6.1\n(25 points)'], 'crimson')

plt.title('Time Series for Students Performance in Test-15', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# Time-series plot for 52 Students Performance in Different tests

plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(data1['Student ID'], data1['ES 6.2\n(15 points)'], 'violet')

plt.title('Time Series for Students Performance in Test-16', fontsize = 30)
plt.xlabel('Students IDs', fontsize = 15)
plt.ylabel('Score',fontsize = 15)
plt.show()

# %%
# plotting a pairplot for intermediate grades data

sns.pairplot(data2)

# %%
# making a data to be clustered for forming groups

# between session1 and session2 scores
x = data2.iloc[:, [1, 2]].values

# getting the shape of x
x.shape
# Out:
# (115, 2)

# %%
#clustering

from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
  km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
  km.fit(x)
  wcss.append(km.inertia_)
  
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('No. of Clusters')
plt.ylabel('wcss')
plt.show()

# %%
km = KMeans(n_clusters = 2, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_means = km.fit_predict(x)

plt.scatter(x[y_means == 0, 0], x[y_means == 0, 1], s = 100, c = 'pink', label = 'Poor Students')
plt.scatter(x[y_means == 1, 0], x[y_means == 1, 1], s = 100, c = 'yellow', label = 'Good Students')
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'blue' , label = 'centeroid')

plt.title('Session1 and Session2 Score', fontsize = 30)
plt.xlabel('Session 1', fontsize = 15)
plt.ylabel('Session 2 ', fontsize = 15)
plt.legend()
plt.show()

# %%
# making another group of clusters

# between student id and total scores
x = data1.iloc[:, [16, 17]].values

# getting the shape of the data
x.shape
# Out:
# (62, 2)

# %%
#clustering

from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
  km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
  km.fit(x)
  wcss.append(km.inertia_)
  
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('No. of Clusters')
plt.ylabel('wcss')
plt.show()

# %%
km = KMeans(n_clusters = 2, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_means = km.fit_predict(x)

plt.scatter(x[y_means == 0, 0], x[y_means == 0, 1], s = 100, c = 'red', label = 'Poor Students')
plt.scatter(x[y_means == 1, 0], x[y_means == 1, 1], s = 100, c = 'green', label = 'Good Students')
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'black' , label = 'centeroid')

plt.title('Test-16 and Total Scores', fontsize = 30)
plt.xlabel('Test-16 Scores', fontsize = 15)
plt.ylabel('Total Scores',  fontsize = 15)
plt.legend()
plt.show()

# %%
# FEATURE ENFINEERING

# adding total marks in data2 i.e., intermediate grade dataset

data2['Total Marks'] = data2['Session 2'] + data2['Session 3'] + data2['Session 4'] + data2['Session 5'] + data2['Session 6']
sns.distplot(data2['Total Marks'], color = 'yellow')
plt.title('Distribution of Total Marks', fontsize = 30)
plt.show()

# %%
# Adding one more feature avg marks

data2['Avg Marks'] = data2['Total Marks']/5

sns.distplot(data2['Avg Marks'], color = 'magenta')
plt.title('Distribution of Average Marks', fontsize = 30)
plt.show()

# %%
# let's predict the avg marks

# splitting the data into dependent and independent data sets

x = data2.iloc[:, :-1]
y = data2.iloc[:, -1]

# checking the shapes
print("Shape of x :", x.shape)
print("Shape of y :", y.shape)
# Out:
# Shape of x : (115, 7)
# Shape of y : (115,)

# %%
# train test split

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# checking the shapes
print("Shape of x_train :", x_train.shape)
print("Shape of x_test :", x_test.shape)
print("Shape of y_train :", y_train.shape)
print("Shape of y_test :", y_test.shape)
# Out:
# Shape of x_train : (92, 7)
# Shape of x_test : (23, 7)
# Shape of y_train : (92,)
# Shape of y_test : (23,)

# %%
# Standard Scaling

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
# Out:
# C:\Users\vinee\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\vinee\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\vinee\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   import sys

# %%
# modelling

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# evaluating the model
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print("RMSE Score :", np.sqrt(mse))

# r2 score
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score :", r2)
# Out:
# RMSE Score : 1.0644480762857211e-15
# R2 Score : 1.0

# %%
# modelling

from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# evaluating the model
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print("RMSE Score :", np.sqrt(mse))

# r2 score
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score :", r2)
# Out:
# RMSE Score : 0.036460222518341204
# R2 Score : 0.9990911411382303
# C:\Users\vinee\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# modelling

from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# evaluating the model
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print("RMSE Score :", np.sqrt(mse))

# r2 score
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score :", r2)
# Out:
# RMSE Score : 0.07223151185146161
# R2 Score : 0.9964329333307484

# %%
# modelling

from sklearn.svm import SVR

model = SVR()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# evaluating the model
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print("RMSE Score :", np.sqrt(mse))

# r2 score
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score :", r2)
# Out:
# RMSE Score : 0.13122739555150992
# R2 Score : 0.9882264661838591
